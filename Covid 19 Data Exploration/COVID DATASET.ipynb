# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd 
import random as rd
from sklearn import datasets
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df= pd.read_csv(r'C:\Users\M_Ampah\Downloads\covid_data.csv')

# %%
df.head()
# Out:
#   Sample  Age   Sex Severity  A1BG  A1CF   A2M  A2ML1  A3GALT2  A4GALT  ...  \
# 0     C1   39  male   NonICU  0.49  0.00  0.21   0.04     0.07     0.0  ...
# 1     C2   63  male   NonICU  0.29  0.00  0.14   0.00     0.00     0.0  ...
# 2     C3   33  male   NonICU  0.26  0.00  0.03   0.02     0.00     0.0  ...
# 3     C4   49  male   NonICU  0.45  0.01  0.09   0.07     0.00     0.0  ...
# 4     C5   49  male   NonICU  0.17  0.00  0.00   0.05     0.07     0.0  ...
#
#    ZWILCH  ZWINT  ZXDA  ZXDB   ZXDC  ZYG11A  ZYG11B     ZYX  ZZEF1  ZZZ3
# 0    2.84   4.22  0.95  1.63  15.51    0.06    8.17  363.01  19.17  6.05
# 1    3.55  12.15  0.60  1.15  15.62    0.14    8.20  399.80  15.72  4.12
# 2    1.34   2.79  0.18  0.32  17.67    0.28    3.62  430.35  13.95  1.81
# 3    3.71   5.87  1.40  2.21  15.61    0.27    7.88  209.25  14.78  7.15
# 4    1.44   4.46  0.28  0.55   9.34    0.07    5.96  272.91   8.69  2.70
#
# [5 rows x 19476 columns]

# %%
df.tail()
# Out:
#     Sample  Age     Sex Severity  A1BG  A1CF   A2M  A2ML1  A3GALT2  A4GALT  \
# 121   NC22   63    male   NonICU  0.30   0.0  0.02   0.02     0.00     0.0
# 122   NC23   42  female   NonICU  0.70   0.0  0.02   0.01     0.00     0.0
# 123   NC24   32  female   NonICU  0.75   0.0  0.27   0.00     0.06     0.0
# 124   NC25   62    male   NonICU  2.80   0.0  0.04   0.00     0.00     0.0
# 125   NC26   36    male      ICU  0.22   0.0  0.28   0.00     0.00     0.0
#
#      ...  ZWILCH  ZWINT  ZXDA  ZXDB   ZXDC  ZYG11A  ZYG11B     ZYX  ZZEF1  \
# 121  ...    0.26   1.01  0.13  0.46   5.93    0.24    1.58  447.14   3.04
# 122  ...    0.64   0.83  0.18  0.73   8.75    0.12    1.57  748.55   4.55
# 123  ...    1.18   2.14  0.41  1.29  14.93    0.14    5.05  437.62  10.34
# 124  ...    0.42   0.61  0.19  0.45   4.77    0.33    1.07  369.66   1.83
# 125  ...    0.32   2.02  0.05  0.10   3.46    0.10    1.25  577.13   2.08
#
#      ZZZ3
# 121  1.00
# 122  1.56
# 123  3.99
# 124  0.96
# 125  0.27
# ...

# %%
df.shape
# Out:
# (126, 19476)

# %%
df.describe(include = 'object')
# Out:
#        Sample   Sex Severity
# count     126   126      126
# unique    126     3        2
# top       C74  male      ICU
# freq        1    74       66

# %%
Severity_map = {'NonICU': 0, 'ICU': 1}
Sex_map = {"male": 0, "female": 1, "unknown": 2}


# Replace column values using map method instead of multiple replace() calls
df['Severity'] = df['Severity'].map(Severity_map)
df['Sex'] = df['Sex'].map(Sex_map)

# %%
df.head()
# Out:
#   Sample  Age  Sex  Severity  A1BG  A1CF   A2M  A2ML1  A3GALT2  A4GALT  ...  \
# 0     C1   39    0         0  0.49  0.00  0.21   0.04     0.07     0.0  ...
# 1     C2   63    0         0  0.29  0.00  0.14   0.00     0.00     0.0  ...
# 2     C3   33    0         0  0.26  0.00  0.03   0.02     0.00     0.0  ...
# 3     C4   49    0         0  0.45  0.01  0.09   0.07     0.00     0.0  ...
# 4     C5   49    0         0  0.17  0.00  0.00   0.05     0.07     0.0  ...
#
#    ZWILCH  ZWINT  ZXDA  ZXDB   ZXDC  ZYG11A  ZYG11B     ZYX  ZZEF1  ZZZ3
# 0    2.84   4.22  0.95  1.63  15.51    0.06    8.17  363.01  19.17  6.05
# 1    3.55  12.15  0.60  1.15  15.62    0.14    8.20  399.80  15.72  4.12
# 2    1.34   2.79  0.18  0.32  17.67    0.28    3.62  430.35  13.95  1.81
# 3    3.71   5.87  1.40  2.21  15.61    0.27    7.88  209.25  14.78  7.15
# 4    1.44   4.46  0.28  0.55   9.34    0.07    5.96  272.91   8.69  2.70
#
# [5 rows x 19476 columns]
